# %%
# !pip install pandas
# Out:
# ...
# distributed 1.21.8 requires msgpack, which is not installed.
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df = pd.read_csv("sources/ads_en_us.csv")

# %%
df['subcatid'] = df['subcatid'].map(lambda x: "True" if x == 27 else "False")

# %%
columns = df.columns

# %%
new_df = df[columns[3:]]
new_df.rename(columns={"subcatid":"id", "value":"text"}, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3778: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
new_df
# Out:
#           id                                               text
# 0       True  Overview \r\n \r\nWhy AFFIRMA Rehabilitation? ...
# 1       True  Overview \r\n \r\nWhy AFFIRMA Rehabilitation? ...
# 2       True  Overview:\r\n\r\nUnder general supervision by ...
# 3      False  Be your own boss working under a Strong Brand ...
# 4      False  Be your own boss working under a Strong Brand ...
# 5      False  Be your own boss working under a Strong Brand ...
# 6      False  Be your own boss working under a Strong Brand ...
# 7      False  Be your own boss working under a Strong Brand ...
# 8      False  Be your own boss working under a Strong Brand ...
# 9      False  Be your own boss working under a Strong Brand ...
# 10     False  Be your own boss working under a Strong Brand ...
# 11     False  Be your own boss working under a Strong Brand ...
# 12     False  Be your own boss working under a Strong Brand ...
# 13     False  Be your own boss working under a Strong Brand ...
# ...

# %%
new_df.to_csv("data/data.csv", sep=',', index=False)
